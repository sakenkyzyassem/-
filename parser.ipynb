# %%
s = bs4.BeautifulSoup(res.text, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e0c274ca8438> in <module>
# ----> 1 s = bs4.BeautifulSoup(res.text, 'lxml')
#
# NameError: name 'bs4' is not defined

# %%
s = bs4.BeautifulSoup(res.text, 'lxml')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e0c274ca8438> in <module>
# ----> 1 s = bs4.BeautifulSoup(res.text, 'lxml')
#
# NameError: name 'bs4' is not defined

# %%
import requests

# %%
import bs4

# %%
res = requests.get('https://tengrinews.kz')

# %%
res.text
# Out:
# '<!DOCTYPE html>\n<html lang="ru">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1">\n    <title>Tengrinews – главные новости Казахстана</title>\n    <meta name="keywords" content="tengrinews, новости казахстана, новости мира, новости алматы, новости спорта, казахстан"/>\n    <meta name="description" content="Tengrinews.kz - главные новости Казахстана, России и мира о бизнесе, экономике, происшествиях, спорте"/>\n    <meta name="theme-color" content="green">\n    <meta name="telegram:channel" content="@tengrinews">\n    <meta name="verify-admitad" content="d44c35787b"/>\n    <meta property="fb:pages" content="129433987143403"/>\n            <link href="/amp/" rel="amphtml">\n                \n            <link rel="canonical"\n              href="https://tengrinews.kz/">\n        <!-- pagination -->\n            <link rel="manifest" href="/manifest.json">\n\n    <!--
# ...

# %%
import re

# %%
soup = bs4.BeautifulSoup(res.text, 'lxml')

# %%
soup.find_all(a=re.compile("Кино"))
# Out:
# []
